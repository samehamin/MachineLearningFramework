# %%
import numpy as np

# %% [markdown]
# # 6.1 Univariate Plots

# %% [markdown]
# ## Histograms

# %%
# Univariate Histograms
from matplotlib import pyplot
from pandas import read_csv
filename = "pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
data = read_csv(filename, names=names)
data.hist()
pyplot.show()

# %% [markdown]
# ## Density Plots

# %%
# Univariate Density Plots
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
pyplot.show()

# %% [markdown]
# ## Box and Whisker Plots

# %%
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False) 
pyplot.show()
# We can see that the spread of attributes is quite different. Some like age, test and skin
# appear quite skewed towards smaller values.

# %% [markdown]
# # 6.2 Multivariate Plots

# %% [markdown]
# ## Correlation Matrix Plot
# If two variables change in the same direction they are positively correlated. If they change in opposite directions together (one goes up, one goes down), then they are negatively correlated. <br/>
# some machine learning algorithms like linear and logistic regression can have poor performance if there are highly correlated input variables in your data.

# %%
# Correction Matrix Plot
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %% [markdown]
# The example is not generic in that it specifies the names for the attributes along the axes as well as the number of ticks. This recipe can be made more generic by removing these aspects as follows:

# %%
# Correction Matrix Plot (generic)
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
pyplot.show()

# %% [markdown]
# ## Scatter Plot Matrix
# A scatter plot shows the relationship between two variables as dots in two dimensions <br/>
# Scatter plots are useful for spotting structured relationships between variables <br/>

# %%
# Scatterplot Matrix
from pandas.plotting import scatter_matrix
scatter_matrix(data)
pyplot.show()
